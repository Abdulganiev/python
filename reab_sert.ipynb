# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from keyboard import press_and_release
from time import sleep
import pyperclip
import pyautogui as pag

# %%
def paste(text: str):    
    pyperclip.copy(text)
    press_and_release('ctrl + v')


def type(text: str, interval=0.0):    
    buffer = pyperclip.paste()
    if not interval:
        paste(text)
    else:
        for char in text:
            paste(char)
            sleep(interval)
    pyperclip.copy(buffer)
    
    
def okno():    
#     pag.hotkey('altleft', 'tab')
    pag.keyDown("altleft")
    pag.press("tab")
    pag.keyUp("altleft")
    pag.press("enter")

def hom(text, o):
    pag.press("home")
    pag.moveTo(1200, 340, 4)
    pag.click()
    pag.moveTo(590, 385, 4)
    pag.click()

    past(text)
    pag.press("esc")

    if o == 1: # обязательный или нет
        pag.moveTo(580, 480, 1.5)
        pag.click()
    else:
        pag.moveTo(1200, 490, 1.5)
        pag.click()
    
    pag.press("end")
    
    pag.moveTo(580, 490, 1.5)
    pag.click()
    
def gu_str(text, o):
    hom(text, o)
    type('11', 1.5)
    pag.press("enter")
    pag.moveTo(565, 775, 1.5)
    pag.click()
    pag.press('enter')
    
def gu_dat(text, o):
    hom(text, o)
    type('3', 1.5)
    pag.press("enter")
    pag.press('enter')
    
def gu_mail(text, o):
    hom(text, o)
    type('1', 1.5)
    pag.press("enter")
    pag.press('enter')
    
def gu_com(text, o):
    hom(text,  0)
    type('12', 1.5)
    pag.press("enter")
    pag.press('enter')
    
def gu_mesto(text, o):
    hom(text,  o)
    text2 = 'указываются на основании записи в документе, удостоверяющем личность, или ином документе, подтверждающем постоянное проживание заявителя на территории Ямало-Ненецкого автономного округа'
    pag.moveTo(565, 450, 1.5)
    pag.click()
    past(text2)

    pag.moveTo(580, 490, 1.5)
    pag.click()
    type('11', 1.5)
    pag.press("enter")
    pag.moveTo(565, 775, 1.5)
    pag.click()
    pag.press('enter')
    
def sogl(text):
    hom(text,  1)
    type('6', 2)
    pag.press("enter")
    pag.moveTo(565, 560, 1.5)
    pag.click()
    pag.moveTo(565, 595, 1.5)
    pag.click()
    type('Да', 0.5)
    pag.press("enter")

# %%
def opek1():
    text = 'Прошу'
    hom(text,  1)
    t1 = 'передать мне под опеку (попечительство)'
    t2 = 'передать мне под опеку (попечительство) на возмездной основе'
    type('6', 1)
    pag.press("enter")
    pag.moveTo(565, 560, 1.5)
    pag.click()
    pag.moveTo(565, 595, 1.5)
    pag.click()
    past(t1)
    pag.press("esc")
    
    pag.moveTo(565, 705, 1.5)
    pag.click()        
    pag.moveTo(565, 745, 1.5)
    pag.click()
    past(t2)
    pag.press("enter")

# %%
def opek2():
    text = 'Дополнительно могу сообщить о себе следующее'
    t = 'указывается наличие у гражданина необходимых знаний и навыков в осуществлении опеки (попечительства) над совершеннолетним недееспособным или не полностью дееспособным гражданином, в том числе информация о наличии документов о профессиональной деятельности, о прохождении программ подготовки кандидатов в опекуны или попечители и т.д.'
    hom(text,  1)
    
    pag.moveTo(565, 165, 1.5)
    pag.click()
    past(t)
    pag.press("esc")
    
    pag.moveTo(565, 500, 1.5)
    pag.click()
    type('9', 1.5)
    pag.press("enter")
    pag.press("enter")

# %%
def past(text):
    pyperclip.copy(text)
    pag.hotkey('ctrl', 'v')

# %%
def status_sert():
    text = 'Статус лица, имеющего право на получение реабилитационного сертификата:'
    hom(text,  1)
    t1 = 'Мать'
    t2 = 'Отец'
    t3 = 'Ребенок'
    type('6', 1)
    pag.press("enter")
    pag.moveTo(565, 560, 1.5)
    pag.click()
    pag.moveTo(565, 595, 1.5)
    pag.click()
    past(t1)
    pag.press("esc")
    
    pag.moveTo(565, 705, 1.5)
    pag.click()        
    pag.moveTo(565, 745, 1.5)
    pag.click()
    past(t2)
    pag.press("esc")
    
    pag.moveTo(565, 845, 1.5)
    pag.click()
    pag.press("end")
    pag.moveTo(565, 315, 1.5)
    pag.click()
    past(t3)
    pag.press("enter")

# %%
def gragd():
    text = 'Сведения о принадлежности к гражданству:'
    hom(text,  1)
    t1 = 'Гражданин Российской Федерации'
    t2 = 'Иностранный гражданин'
    t3 = 'Лицо без гражданства'
    type('6', 1)
    pag.press("enter")
    pag.moveTo(565, 560, 1.5)
    pag.click()
    pag.moveTo(565, 595, 1.5)
    pag.click()
    past(t1)
    pag.press("esc")
    
    pag.moveTo(565, 705, 1.5)
    pag.click()        
    pag.moveTo(565, 745, 1.5)
    pag.click()
    past(t2)
    pag.press("esc")
    
    pag.moveTo(565, 845, 1.5)
    pag.click()
    pag.press("end")
    pag.moveTo(565, 315, 1.5)
    pag.click()
    past(t3)
    pag.press("enter")

# %%
def sert_vid():
    text = 'Прошу выдать мне:'
    hom(text,  1)
    t1 = 'Реабилитационный сертификат'
    t2 = 'Дубликат реабилитационного сертификата '
    type('6', 1)
    pag.press("enter")
    pag.moveTo(565, 560, 1.5)
    pag.click()
    pag.moveTo(565, 595, 0.5)
    pag.click()
    past(t1)
    pag.press("esc")
    
    pag.moveTo(565, 705, 1.5)
    pag.click()        
    pag.moveTo(565, 745, 1.5)
    pag.click()
    past(t2)
    pag.press("enter")
    
def variant2(text, t1, t2):
    hom(text,  1)
    type('6', 1)
    pag.press("enter")
    pag.moveTo(565, 560, 1.5)
    pag.click()
    pag.moveTo(565, 595, 1.5)
    pag.click()
    past(t1)
    pag.press("esc")
    
    pag.moveTo(565, 705, 1.5)
    pag.click()        
    pag.moveTo(565, 745, 1.5)
    pag.click()
    past(t2)
    pag.press("enter")
    
def in_file(text):
    hom(text,  0)
    type('4', 1)
    pag.press("enter")
    pag.press("enter")

# %%
def zayav():
    pag.moveTo(1269, 327, 1.5)
    pag.click()
    sleep(4)
    pag.press("end")
    pag.moveTo(617, 294, 3.5)
    pag.click()
    pag.moveTo(1245, 345, 3.5)
    pag.click()
    pag.moveTo(555, 390, 3.5)
    pag.click()
    text = 'Данные заявления'
    past(text)
    pag.press("enter")
    pag.moveTo(1245, 415, 3.5)
    pag.click()

# %%
pag.FAILSAFE = True
okno()

zayav()

gu_com('Сведения о заявителе', 0)
status_sert()
gragd()
gu_mesto('Сведения о месте жительства', 1)


gu_str('Контактный телефон', 1)
gu_mail('Адрес электронной почты', 1)
gu_dat('Дата рождения заявителя', 1)
gu_com('Сведения о документе, удостоверяющем личность :', 0)
gu_str('Наименование документа, удостоверяющего личность', 1)
gu_str('Серия и номер', 1)
gu_str('Кем выдан', 1)
gu_dat('Когда выдан', 1)
gu_str('Код подразделения', 1)
gu_str('Место рождения', 1)
gu_str('Страховой номер индивидуального лицевого счета (СНИЛС)', 1)
gu_str('Идентификационный номер налогоплательщика физического лица (ИНН)', 1)
sert_vid()

gu_com('Сведения о ребенке-инвалиде:', 0)
gu_str('Фамилия, имя, отчество', 1)
gu_dat('Дата рождения', 1)
gu_str('Место рождения', 1)
gragd()
variant2('Пол', 'Мужской', 'Женский')

gu_com('Реквизиты свидетельства о рождении:', 0)
gu_str('Серия и номер', 1)
gu_dat('Дата выдачи', 1)
gu_str('Номер акта о рождении', 1)
gu_str('Место государственной регистрации', 1)
gu_str('Страховой номер индивидуального лицевого счета (СНИЛС)', 1)
gu_str('Реквизиты документа, подтверждающего усыновление ребенка, признанного инвалидом, либо установление опеки или попечительства, принятие в приемную семью', 0)
gu_mesto('Сведения о месте жительства ребенка-инвалида ', 1)

variant2('Родительских прав в отношении ребенка:', 'не лишалась(ся)', 'лишалась(ся)')

sogl('Умышленных преступлений, относящихся к преступлениям против личности, в отношении своего ребенка (детей) не совершала (не совершал)')

gu_com('Сведения о ранее выданном реабилитационном сертификате с указанием обстоятельств его утраты (порчи) (в случае обращения за дубликатом реабилитационного сертификата:', 0)

gu_str('Серия и номер сертификата', 0)
gu_dat('Дата выдачи сертификата', 0)
gu_str('Кем выдан сертификата', 0)
gu_str('Обстоятельства утраты (порчи) сертификата', 0)

sogl('Достоверность представленных сведений, указанных в заявлении о выдаче реабилитационного сертификата/дубликата реабилитационного сертификата, подтверждаю')

sogl('Об ответственности за недостоверность представленных сведений проинформирован')

sogl('Я даю согласие на обработку персональных данных')

variant2('Способ получения реабилитационного сертификата:', 'Лично', 'По почте')

in_file('К заявлению прилагаю следующие документы:')

# %%
okno()
print(pag.position())
# Out:
# Point(x=1244, y=414)
